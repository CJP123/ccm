# %% [raw]
# ---
# description: Create a continuous colormap for matplotlib based on a paired list of
#   colors and scales.
# output-file: cmap.html
# title: Continuous Colormap
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(get_continuous_cmap)
# Out:
# ---
#
# [source](https://github.com/CJP123/continuous_cmap/blob/main/continuous_cmap/cmap.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### get_continuous_cmap
#
# >      get_continuous_cmap (hex_list:list[str], float_list:list[float])
#
# creates and returns a color map that can be used in heat map figures.
# If float_list is not provided, colour map graduates linearly between each color in hex_list.
# If float_list is provided, each color in hex_list is mapped to the respective location in float_list.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | hex_list | list | list of hex code strings |
# | float_list | list | list of floats code strings |
# | **Returns** | **LinearSegmentedColormap** |  |

# %%
cmap_1000 = get_continuous_cmap(['#2AA364', '#F5EB4D', '#9E4229', '#381D02', '#381D02', '#381D02'], float_list=[0, 0.15, .6,.75,.8,1])
cmap_1000
